# %% [markdown]
# # DataSense AI EDA
#
# This notebook helps inspect the churn dataset before training.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from src.feature_engineering import summarize_dataframe

df = pd.read_csv('../data/raw/churn.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       2 import seaborn as sns
#       3 import matplotlib.pyplot as plt
# ----> 5 from src.feature_engineering import summarize_dataframe
#       7 df = pd.read_csv('../data/raw/churn.csv')
#       8 df.head()
#
# ModuleNotFoundError: No module named 'src'

# %%
summary = summarize_dataframe(df)
summary

# %%
sns.countplot(data=df, x='Churn Label')
plt.title('Churn Distribution')
plt.xticks(rotation=0)
plt.show()

# %%
numeric_cols = ['Tenure Months', 'Monthly Charges', 'Total Charges', 'CLTV']
df[numeric_cols].hist(figsize=(12, 8))
plt.tight_layout()
plt.show()
