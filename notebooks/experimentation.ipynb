# %% [markdown]
# # Model Experimentation
#
# Use this notebook to run the training pipeline and inspect model results.

# %%
from src.model_training import train_and_select_model

artifact = train_and_select_model('../config.yaml')
artifact['model_name']

# %%
artifact['all_results']

# %%
artifact['processed_paths']
